# %%
import pandas as pd


df = pd.read_excel(r"/Users/razanm/Desktop/sample.xlsx")
d=df.sample(10)

d
# Out:
#                    Date Region         City  Category         Product  Qty  \
# 119  ID07470 2022-12-24   East     New York   Cookies       Arrowroot  237
# 175  ID07526 2023-06-09   East       Boston  Crackers     Whole Wheat   26
# 42   ID07393 2022-05-07   East       Boston   Cookies  Oatmeal Raisin  138
# 37   ID07388 2022-04-22   West  Los Angeles      Bars          Carrot   20
# 233  ID07584 2023-11-30   East       Boston  Crackers     Whole Wheat   20
# 91   ID07442 2022-10-01   East       Boston      Bars          Carrot   77
# 35   ID07386 2022-04-16   East       Boston      Bars          Carrot   48
# 211  ID07562 2023-09-25   East       Boston      Bars          Carrot   31
# 68   ID07419 2022-07-24   West    San Diego      Bars            Bran   51
# 0    ID07351 2022-01-01   East       Boston      Bars          Carrot   33
#
#      UnitPrice  TotalPrice
# 119       2.18      516.66
# 175       3.49       90.74
# 42        2.84      391.92
# 37        1.77       35.40
# ...

# %%
import matplotlib.pyplot as plt
x = d['Qty']
y = d['TotalPrice'] 
plt.plot(x, y)
plt.title("Graphic representation")
plt.xlabel(" horizontal (x) Qty ")
plt.ylabel("vertical (y) TotalPrice ")
plt.show()
